# %%
from selenium import webdriver
from selenium.webdriver.support.ui import Select
from bs4 import BeautifulSoup
from time import sleep
import requests
import json
import pandas as pd

# %%
with open('account.json') as f:
    account = json.load(f);

my_id = account['id']
my_pw = account['password']

driver = webdriver.Chrome('chromedriver.exe')
driver.get('https://rankingdak.com/')
driver.find_element_by_xpath('//*[@id="header"]/div[2]/div/ul[1]/li[1]/a').click()
driver.find_element_by_id('login_id').send_keys(my_id)
driver.find_element_by_id('login_pwd').send_keys(my_pw)
driver.find_element_by_class_name('box_btn').click()
sleep(2)
driver.find_element_by_class_name('hm1').click()
driver.find_element_by_class_name('n3').click()
driver.find_element_by_xpath('//*[@id="2322"]/a').click()


select = Select(driver.find_element_by_id('quantity'))
select.select_by_visible_text('300개')
sleep(2)
target_url = driver.current_url

def crawl_login(target_url, filename):
    f = open(filename, 'w', encoding='utf-8')
    page = requests.get(target_url)
    f.write(page.text)
    return page


page = crawl_login(driver.current_url, 'chicken_login.txt')

# %%
soup = BeautifulSoup(page.content.decode('utf-8', 'replace'), 'html.parser')
all_tags = soup.find_all(class_='col3')
name_tags = all_tags[0].select('.prd_name')
price_tags = all_tags[0].select('.price')
unit = all_tags[0].select('.price_unit')

# %%
chicken_name=[]
chicken_price=[]
for name in name_tags:
    chicken_name.append(name.text.strip())

for price in price_tags:
    chicken_price.append(price.text.strip())

# %%
cnt = len(chicken_name)
one_plus_idx=0
weight=[]
dic = {}
for i in range(cnt):
    dic[chicken_name[i]]=chicken_price[i]

for i in range(cnt):    
    if chicken_name[i][-1:] != 'g':
        one_plus_idx = i
        chicken_name[i] = chicken_name[i][:-4] + '100g'

# %%
df = pd.DataFrame(chicken_name, columns=['이름'])
df['개수']=10
df.loc[one_plus_idx, '개수']=11 # 10+1 제품 구분해서 개수 11개로 등록 
df['가격']=chicken_price[:120]

# %%
df.sort_values(by='가격', ascending=True)
for i in range(cnt):
    df.loc[i, '가격'] = df.loc[i, '가격'][:-1].replace(',', '')

# %%
pd.set_option('display.max_rows', None)

df.loc[df['이름']=='수지스 수비드 닭가슴살 550g','개수']=3

for i in range(cnt):
    g = pd.Series(df.loc[i, '이름'][-4:-1])
    g[i] = pd.Series(df.loc[i, '이름'][-4:-1])
    df.loc[i, 'g당 가격'] = int(df.loc[i, '가격']) / (int(df.loc[i, '개수']) * int(g[i][0]))

# %%
df.sort_values(by='g당 가격')
# Out:
#                                 이름  개수     가격      g당 가격
# 93               수지스 수비드 닭가슴살 550g   3  15500   9.393939
# 92               수지스 수비드 닭가슴살 550g   3  15500   9.393939
# 59            햇살닭 페퍼콘 스팀 닭가슴살 200g  10  20850  10.425000
# 58            햇살닭 페퍼콘 스팀 닭가슴살 200g  10  20850  10.425000
# 115       닭가슴살한끼 한끼통살 닭가슴살 갈릭 100g  10  11500  11.500000
# 114       닭가슴살한끼 한끼통살 닭가슴살 갈릭 100g  10  11500  11.500000
# 113         네이처온 스팀 닭가슴살 오리지널 100g  10  11500  11.500000
# 112         네이처온 스팀 닭가슴살 오리지널 100g  10  11500  11.500000
# 117             매일먹닭 촉촉한 닭가슴살 100g  10  12500  12.500000
# 116             매일먹닭 촉촉한 닭가슴살 100g  10  12500  12.500000
# 118      바디나인 촉촉한 한입 닭가슴살 마늘맛 100g  10  12500  12.500000
# 119      바디나인 촉촉한 한입 닭가슴살 마늘맛 100g  10  12500  12.500000
# 57           햇살닭 흑마늘 수비드 닭가슴살 150g  10  20850  13.900000
# 56           햇살닭 흑마늘 수비드 닭가슴살 150g  10  20850  13.900000
# 51          더프레시 10초 수비드 닭가슴살 150g  10  20850  13.900000
# 50          더프레시 10초 수비드 닭가슴살 150g  10  20850  13.900000
# 100      매니지 워터바스 수비드 닭가슴살 바질 100g  10  14900  14.900000
# 101      매니지 워터바스 수비드 닭가슴살 바질 100g  10  14900  14.900000
# 102     매니지 워터바스 수비드 닭가슴살 장조림 100g  10  14900  14.900000
# 103     매니지 워터바스 수비드 닭가슴살 장조림 100g  10  14900  14.900000
# 0             맛있닭 스팀 닭가슴살 고추맛 100g  10  15500  15.500000
# 91           허닭 리얼수비드 닭가슴살 혼합 100g  10  15500  15.500000
# 90           허닭 리얼수비드 닭가슴살 혼합 100g  10  15500  15.500000
# 89         허닭 리얼수비드 닭가슴살 갈릭허브 100g  10  15500  15.500000
# 88         허닭 리얼수비드 닭가슴살 갈릭허브 100g  10  15500  15.500000
# 87         허닭 리얼수비드 닭가슴살 칠리페퍼 100g  10  15500  15.500000
# 85            허닭 스팀 닭가슴살 탄두리맛 100g  10  15500  15.500000
# 8            맛있닭 소프트 닭가슴살 마늘맛 100g  10  15500  15.500000
# 84            허닭 스팀 닭가슴살 탄두리맛 100g  10  15500  15.500000
# 83             허닭 스팀 닭가슴살 깻잎맛 100g  10  15500  15.500000
# 82             허닭 스팀 닭가슴살 깻잎맛 100g  10  15500  15.500000
# 81              허닭 스팀 닭가슴살 혼합 100g  10  15500  15.500000
# 80              허닭 스팀 닭가슴살 혼합 100g  10  15500  15.500000
# 11           맛있닭 소프트 닭가슴살 고추맛 100g  10  15500  15.500000
# 10           맛있닭 소프트 닭가슴살 고추맛 100g  10  15500  15.500000
# 86         허닭 리얼수비드 닭가슴살 칠리페퍼 100g  10  15500  15.500000
# 7           맛있닭 소프트 닭가슴살 탄두리맛 100g  10  15500  15.500000
# 94    밀스원 올핏 소프트 스팀 닭가슴살 오리지널 100g  10  15500  15.500000
# 95    밀스원 올핏 소프트 스팀 닭가슴살 오리지널 100g  10  15500  15.500000
# 1             맛있닭 스팀 닭가슴살 고추맛 100g  10  15500  15.500000
# 2             맛있닭 스팀 닭가슴살 마늘맛 100g  10  15500  15.500000
# 3             맛있닭 스팀 닭가슴살 마늘맛 100g  10  15500  15.500000
# 4              맛있닭 스팀 닭가슴살 혼합 100g  10  15500  15.500000
# 5              맛있닭 스팀 닭가슴살 혼합 100g  10  15500  15.500000
# 6           맛있닭 소프트 닭가슴살 탄두리맛 100g  10  15500  15.500000
# 111      바비뚝닭 담백한 스팀 닭가슴살 마늘맛 100g  10  15500  15.500000
# 9            맛있닭 소프트 닭가슴살 마늘맛 100g  10  15500  15.500000
# 109      바비뚝닭 담백한 스팀 닭가슴살 고추맛 100g  10  15500  15.500000
# 110      바비뚝닭 담백한 스팀 닭가슴살 마늘맛 100g  10  15500  15.500000
# 107      매니지 워터바스 수비드 닭가슴살 혼합 100g  10  15500  15.500000
# 106      매니지 워터바스 수비드 닭가슴살 혼합 100g  10  15500  15.500000
# 105    매니지 워터바스 수비드 닭가슴살 청양고추 100g  10  15500  15.500000
# 104    매니지 워터바스 수비드 닭가슴살 청양고추 100g  10  15500  15.500000
# 99      밀스원 올핏 소프트 스팀 닭가슴살 혼합 100g  10  15500  15.500000
# 98      밀스원 올핏 소프트 스팀 닭가슴살 혼합 100g  10  15500  15.500000
# 97     밀스원 올핏 소프트 스팀 닭가슴살 훈제맛 100g  10  15500  15.500000
# 96     밀스원 올핏 소프트 스팀 닭가슴살 훈제맛 100g  10  15500  15.500000
# 108      바비뚝닭 담백한 스팀 닭가슴살 고추맛 100g  10  15500  15.500000
# 67             탉 닭가슴살 스팀뿜뿜 혼합 100g  10  15900  15.900000
# 66             탉 닭가슴살 스팀뿜뿜 혼합 100g  10  15900  15.900000
# 64             탉 닭가슴살 스팀뿜뿜 칠리 100g  10  15900  15.900000
# 65             탉 닭가슴살 스팀뿜뿜 칠리 100g  10  15900  15.900000
# 71             아임닭 쉐프메이드 닭가슴살 100g  11  19500  17.727273
# 12            맛있닭 소프트 닭가슴살 혼합 100g  10  17900  17.900000
# 27          잇메이트 소프트 닭가슴살 고추맛 100g  10  17900  17.900000
# 26          잇메이트 소프트 닭가슴살 고추맛 100g  10  17900  17.900000
# 25          잇메이트 소프트 닭가슴살 마늘맛 100g  10  17900  17.900000
# 24          잇메이트 소프트 닭가슴살 마늘맛 100g  10  17900  17.900000
# 23         잇메이트 소프트 닭가슴살 오리지널 100g  10  17900  17.900000
# 22         잇메이트 소프트 닭가슴살 오리지널 100g  10  17900  17.900000
# 21            잇메이트 스팀 닭가슴살 혼합 100g  10  17900  17.900000
# 20            잇메이트 스팀 닭가슴살 혼합 100g  10  17900  17.900000
# 19           잇메이트 스팀 닭가슴살 고추맛 100g  10  17900  17.900000
# 18           잇메이트 스팀 닭가슴살 고추맛 100g  10  17900  17.900000
# 16           잇메이트 스팀 닭가슴살 마늘맛 100g  10  17900  17.900000
# 13            맛있닭 소프트 닭가슴살 혼합 100g  10  17900  17.900000
# 14          잇메이트 스팀 닭가슴살 오리지널 100g  10  17900  17.900000
# 15          잇메이트 스팀 닭가슴살 오리지널 100g  10  17900  17.900000
# 17           잇메이트 스팀 닭가슴살 마늘맛 100g  10  17900  17.900000
# 34   리얼원 무항생제 닭가슴살 수비드 바질&올리브 115g  10  20850  18.130435
# 35   리얼원 무항생제 닭가슴살 수비드 바질&올리브 115g  10  20850  18.130435
# 36     리얼원 무항생제 닭가슴살 수비드 하바네로 115g  10  20850  18.130435
# 37     리얼원 무항생제 닭가슴살 수비드 하바네로 115g  10  20850  18.130435
# 38       리얼원 무항생제 닭가슴살 수비드 혼합 115g  10  20850  18.130435
# 39       리얼원 무항생제 닭가슴살 수비드 혼합 115g  10  20850  18.130435
# 73            굳닭 스팀 닭가슴살 오리지널 100g  10  19500  19.500000
# 74          굳닭 닭가슴살 스팀&훈제닭가슴살 100g  10  19500  19.500000
# 69          아임닭 맛있는 닭가슴살 오리지날 100g  10  19500  19.500000
# 70             아임닭 쉐프메이드 닭가슴살 100g  10  19500  19.500000
# 72            굳닭 스팀 닭가슴살 오리지널 100g  10  19500  19.500000
# 79             허닭 스팀 닭가슴살 고추맛 100g  10  19500  19.500000
# 78             허닭 스팀 닭가슴살 고추맛 100g  10  19500  19.500000
# 77             허닭 스팀 닭가슴살 마늘맛 100g  10  19500  19.500000
# 76             허닭 스팀 닭가슴살 마늘맛 100g  10  19500  19.500000
# 75          굳닭 닭가슴살 스팀&훈제닭가슴살 100g  10  19500  19.500000
# 68          아임닭 맛있는 닭가슴살 오리지날 100g  10  19500  19.500000
# 28           잇메이트 소프트 닭가슴살 훈제 100g  10  20850  20.850000
# 29           잇메이트 소프트 닭가슴살 훈제 100g  10  20850  20.850000
# 30           잇메이트 소프트 닭가슴살 혼합 100g  10  20850  20.850000
# 62             탉 닭가슴살 스팀뿜뿜 갈릭 100g  10  20850  20.850000
# 32          러브잇 소프트 닭가슴살 오리지널 100g  10  20850  20.850000
# 63             탉 닭가슴살 스팀뿜뿜 갈릭 100g  10  20850  20.850000
# 60        햇살닭 페퍼콘 스팀 닭가슴살 플러스 100g  10  20850  20.850000
# 55                햇살닭 레몬 닭가슴살 100g  10  20850  20.850000
# 54                햇살닭 레몬 닭가슴살 100g  10  20850  20.850000
# 53                햇살닭 카레 닭가슴살 100g  10  20850  20.850000
# 52                햇살닭 카레 닭가슴살 100g  10  20850  20.850000
# 49            더프레시 스팀 닭가슴살 혼합 100g  10  20850  20.850000
# 48            더프레시 스팀 닭가슴살 혼합 100g  10  20850  20.850000
# 47            더프레시 스팀 닭가슴살 카레 100g  10  20850  20.850000
# 46            더프레시 스팀 닭가슴살 카레 100g  10  20850  20.850000
# 45            더프레시 스팀 닭가슴살 고추 100g  10  20850  20.850000
# 44            더프레시 스팀 닭가슴살 고추 100g  10  20850  20.850000
# 43            더프레시 스팀 닭가슴살 마늘 100g  10  20850  20.850000
# 42            더프레시 스팀 닭가슴살 마늘 100g  10  20850  20.850000
# 41          더프레시 스팀 닭가슴살 오리지널 100g  10  20850  20.850000
# 61        햇살닭 페퍼콘 스팀 닭가슴살 플러스 100g  10  20850  20.850000
# 33          러브잇 소프트 닭가슴살 오리지널 100g  10  20850  20.850000
# 31           잇메이트 소프트 닭가슴살 혼합 100g  10  20850  20.850000
# 40          더프레시 스팀 닭가슴살 오리지널 100g  10  20850  20.850000

# %%
df.loc[df['이름']=='수지스 수비드 닭가슴살 550g','개수']=3
